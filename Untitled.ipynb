# %%
import pandas as pd
import matplotlib as mpl 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Merged.csv')

# %%
df.head()
# Out:
#                   name  year_start                                college  \
# 0       Alaa Abdelnaby        1991                        Duke University
# 1       Alaa Abdelnaby        1991                        Duke University
# 2       Alaa Abdelnaby        1991                        Duke University
# 3       Alaa Abdelnaby        1991                        Duke University
# 4  Kareem Abdul-Jabbar        1970  University of California, Los Angeles
#
#    division  fame    YEAR     G POS  TRB%  STL%  BLK%     PTS  AST%
# 0         1     0  1993.0  75.0  PF  14.6   1.0   1.2   578.0   3.0
# 1         1     0  1993.0  12.0  PF  13.4   1.9   1.6    64.0   9.5
# 2         1     0  1995.0  54.0  PF  13.1   1.5   1.8   256.0   5.0
# 3         1     0  1995.0  51.0  PF  13.0   1.6   1.9   254.0   5.3
# 4         0     1  1982.0  76.0   C  13.4   1.1   4.1  1818.0  11.9

# %%
name = df.groupby('college')['name'].count().sort_values(ascending = False).head(10).index

# %%
x

# %%
import seaborn as sns

# %%
sns.countplot(data = df[(df['college'].isin(x)) & (df['YEAR'] > 2010)],
             x = 'YEAR',
             hue = 'college',
)
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='count'>

# %%
df[df['division'] == 1].groupby('college')['name'].count().sort_values(ascending = False).head(10).index.tolist()
# Out:
# ['Duke University',
#  'University of Kentucky',
#  'University of Arizona',
#  'University of Michigan',
#  'University of Kansas',
#  'Michigan State University',
#  'Georgetown University',
#  'University of Connecticut',
#  'University of Maryland',
#  'University of Arkansas']

# %%
a = pd.crosstab(df[df['YEAR'] > 2000]['YEAR'], df[df['college'].isin(x)].college)
a
# Out:
# college  Duke University  Georgia Institute of Technology  \
# YEAR
# 2001.0                13                                9
# 2002.0                 7                               10
# 2003.0                10                                9
# 2004.0                 7                               13
# 2005.0                10                               11
# 2006.0                 9                                6
# 2007.0                13                                4
# 2008.0                12                                9
# 2009.0                13                               11
# 2010.0                12                                6
# 2011.0                13                                8
# 2012.0                15                                6
# 2013.0                22                                9
# 2014.0                15                                8
# 2015.0                24                               12
# ...

# %%
a['Duke University']
# Out:
# YEAR
# 2001.0    13
# 2002.0     7
# 2003.0    10
# 2004.0     7
# 2005.0    10
# 2006.0     9
# 2007.0    13
# 2008.0    12
# 2009.0    13
# 2010.0    12
# 2011.0    13
# 2012.0    15
# 2013.0    22
# 2014.0    15
# 2015.0    24
# 2016.0    18
# 2017.0    25
# Name: Duke University, dtype: int64

# %%
a.plot(figsize = (8,8))
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
fig, ax = plt.subplots()

ax.plot(a)
ax.legend(name)

# %%
a.index
# Out:
# Float64Index([2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0,
#               2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0,
#               2017.0],
#              dtype='float64', name='YEAR')

# %%
fig, ax = plt.subplots()

ax.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-e89a94a6c67b> in <module>
#       1 fig, ax = plt.subplots()
#       2
# ----> 3 ax.plot(df.groupby(['college', 'YEAR'])['name'].count())
#
# ~\miniconda3\envs\cs_ftmle\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~\miniconda3\envs\cs_ftmle\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
# ...
